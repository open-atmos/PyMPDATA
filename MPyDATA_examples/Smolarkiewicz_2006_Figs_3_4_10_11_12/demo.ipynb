# %%
import sys
sys.path.insert(0, "../..")

from MPyDATA_examples.Smolarkiewicz_2006_Figs_3_4_10_11_12.simulation import Simulation
from MPyDATA_examples.Smolarkiewicz_2006_Figs_3_4_10_11_12.setup import Setup

import numpy as np
import matplotlib.pyplot as plt

# %%
setup = Setup()

# %%
setup.n_iters = 1
simulation = Simulation(setup)
psi0 = simulation.mpdata.curr.get().copy()
simulation.run()

plt.plot(psi0)
plt.plot(simulation.mpdata.curr.get())
plt.show()

# %%
setup.n_iters = 2
simulation = Simulation(setup)
psi0 = simulation.mpdata.curr.get().copy()
simulation.run()

plt.plot(psi0)
plt.plot(simulation.mpdata.curr.get())
plt.show()
