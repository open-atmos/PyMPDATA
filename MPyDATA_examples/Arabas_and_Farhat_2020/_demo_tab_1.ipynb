# %%
# license: GPL v3
# authors: Sylwester Arabas, Michael Olesik, Piotr Bartman
# copyright: Jagiellonian University
# based on Tab. 1 from Arabas & Farhat 2020 (https://doi.org/10.1016/j.cam.2019.05.023)

# %%
# %run _demo_common.ipynb

# %%
from MPyDATA_examples.Arabas_and_Farhat_2020.analysis_table_1 import table_1_data
from IPython.core.display import display, HTML

# %%
data = table_1_data()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   53.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  2.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  3.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  5.0min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  5.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  6.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  7.5min remaining:    0.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-16e0c86ac003> in <module>
# ----> 1 data = table_1_data()
#
# ~/devel/MPyDATA/MPyDATA_examples/Arabas_and_Farhat_2020/analysis_table_1.py in table_1_data()
#      26 def table_1_data():
#      27     with parallel_backend('threading', n_jobs=1):
# ---> 28         result = Parallel(verbose=10)(
#      29             delayed(compute_row)(tuple(
#      30                 Simulation(Setup(T=T, C_opt=C_opt, S0=S0))
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     253         # change the default number of processes to -1
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 255             return [func(*args, **kwargs)
#     256                     for func, args, kwargs in self.items]
#     257
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     253         # change the default number of processes to -1
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 255             return [func(*args, **kwargs)
#     256                     for func, args, kwargs in self.items]
#     257
#
# ~/devel/MPyDATA/MPyDATA_examples/Arabas_and_Farhat_2020/analysis_table_1.py in compute_row(simulations)
#      14     row = [simulations[0].setup.T, simulations[0].setup.S0]
#      15     for simulation in simulations:
# ---> 16         f = simulation.run(n_iters=2)
#      17         row.append(
#      18             error_L2_norm(simulation.solvers, simulation.setup, simulation.S, simulation.nt, n_iters=2))
#
# ~/devel/MPyDATA/MPyDATA_examples/Arabas_and_Farhat_2020/simulation.py in run(self, n_iters)
#      74
#      75             for _ in range(self.nt):
# ---> 76                 self.solvers[n_iters].advance(1, self.mu_coeff)
#      77                 t -= self.dt
#      78                 rhs(self.solvers[n_iters].advectee.get(), t)
#
# ~/devel/MPyDATA/MPyDATA/solver.py in advance(self, nt, mu_coeff)
#      41     def advance(self, nt: int, mu_coeff: float = 0):
#      42         assert mu_coeff == 0 or self.options.non_zero_mu_coeff
# ---> 43         wall_time_per_timestep = self.stepper(nt, mu_coeff,
#      44                                               *self.advectee.impl,
#      45                                               *self.advector.impl,
#
# ~/devel/MPyDATA/MPyDATA/stepper.py in __call__(self, nt, mu_coeff, advectee, advectee_bc, advector, advector_bc, g_factor, g_factor_bc, vectmp_a, vectmp_a_bc, vectmp_b, vectmp_b_bc, vectmp_c, vectmp_c_bc, psi_min, psi_min_bc, psi_max, psi_max_bc, beta_up, beta_up_bc, beta_down, beta_down_bc)
#      67                  beta_down, beta_down_bc):
#      68         assert self.n_threads == 1 or numba.get_num_threads() == self.n_threads
# ---> 69         return self.__call(nt, mu_coeff,
#      70                            advectee, advectee_bc,
#      71                            advector, advector_bc,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_for_args(self, *args, **kws)
#     351                 argtypes.append(self.typeof_pyval(a))
#     352         try:
# --> 353             return self.compile(tuple(argtypes))
#     354         except errors.ForceLiteralArg as e:
#     355             # Received request for compiler re-entry with the list of arguments
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, sig)
#     792             self._cache_misses[sig] += 1
#     793             try:
# --> 794                 cres = self._compiler.compile(args, return_type)
#     795             except errors.ForceLiteralArg as e:
#     796                 def folded(args, kws):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, args, return_type)
#      75
#      76     def compile(self, args, return_type):
# ---> 77         status, retval = self._compile_cached(args, return_type)
#      78         if status:
#      79             return retval
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_cached(self, args, return_type)
#      89
#      90         try:
# ---> 91             retval = self._compile_core(args, return_type)
#      92         except errors.TypingError as e:
#      93             self._failed_cache[key] = e
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_core(self, args, return_type)
#     102
#     103         impl = self._get_implementation(args, {})
# --> 104         cres = compiler.compile_extra(self.targetdescr.typing_context,
#     105                                       self.targetdescr.target_context,
#     106                                       impl,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     566     pipeline = pipeline_class(typingctx, targetctx, library,
#     567                               args, return_type, flags, locals)
# --> 568     return pipeline.compile_extra(func)
#     569
#     570
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(self, func)
#     337         self.state.lifted = ()
#     338         self.state.lifted_from = None
# --> 339         return self._compile_bytecode()
#     340
#     341     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_bytecode(self)
#     399         """
#     400         assert self.state.func_ir is None
# --> 401         return self._compile_core()
#     402
#     403     def _compile_ir(self):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_core(self)
#     370             res = None
#     371             try:
# --> 372                 pm.run(self.state)
#     373                 if self.state.cr is not None:
#     374                     break
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in run(self, state)
#     330                 pass_inst = _pass_registry.get(pss).pass_inst
#     331                 if isinstance(pass_inst, CompilerPass):
# --> 332                     self._runPass(idx, pass_inst, state)
#     333                 else:
#     334                     raise BaseException("Legacy pass in use")
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     289             mutated |= check(pss.run_initialization, internal_state)
#     290         with SimpleTimer() as pass_time:
# --> 291             mutated |= check(pss.run_pass, internal_state)
#     292         with SimpleTimer() as finalize_time:
#     293             mutated |= check(pss.run_finalizer, internal_state)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in check(func, compiler_state)
#     262
#     263         def check(func, compiler_state):
# --> 264             mangled = func(compiler_state)
#     265             if mangled not in (True, False):
#     266                 msg = ("CompilerPass implementations should return True/False. "
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in run_pass(self, state)
#      90                               % (state.func_id.func_name,)):
#      91             # Type inference
# ---> 92             typemap, return_type, calltypes = type_inference_stage(
#      93                 state.typingctx,
#      94                 state.func_ir,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in type_inference_stage(typingctx, interp, args, return_type, locals, raise_errors)
#      68
#      69         infer.build_constraint()
# ---> 70         infer.propagate(raise_errors=raise_errors)
#      71         typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      72
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in propagate(self, raise_errors)
#     976             # Errors can appear when the type set is incomplete; only
#     977             # raise them when there is no progress anymore.
# --> 978             errors = self.constraints.propagate(self)
#     979             newtoken = self.get_state_token()
#     980             self.debug.propagate_finished()
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in propagate(self, typeinfer)
#     147                                                    lineno=loc.line):
#     148                 try:
# --> 149                     constraint(typeinfer)
#     150                 except ForceLiteralArg as e:
#     151                     errors.append(e)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in __call__(self, typeinfer)
#     485                 fnty = typevars[self.func].getone()
#     486             with new_error_context("resolving callee type: {0}", fnty):
# --> 487                 self.resolve(typeinfer, typevars, fnty)
#     488
#     489     def resolve(self, typeinfer, typevars, fnty):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in resolve(self, typeinfer, typevars, fnty)
#     505         # Resolve call type
#     506         try:
# --> 507             sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     508         except ForceLiteralArg as e:
#     509             # Adjust for bound methods
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in resolve_call(self, fnty, pos_args, kw_args)
#    1449         else:
#    1450             # Normal non-recursive call
# -> 1451             return self.context.resolve_function_type(fnty, pos_args, kw_args)
#    1452
#    1453     def typeof_global(self, inst, target, gvar):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/context.py in resolve_function_type(self, func, args, kws)
#     195         # Prefer user definition first
#     196         try:
# --> 197             res = self._resolve_user_function_type(func, args, kws)
#     198         except errors.TypingError as e:
#     199             # Capture any typing error
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/context.py in _resolve_user_function_type(self, func, args, kws, literals)
#     247         if isinstance(func, types.Callable):
#     248             # XXX fold this into the __call__ attribute logic?
# --> 249             return func.get_call_type(self, args, kws)
#     250
#     251     def _get_attribute_templates(self, typ):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/types/functions.py in get_call_type(self, context, args, kws)
#     275         is available for it.
#     276         """
# --> 277         template, pysig, args, kws = self.dispatcher.get_call_template(args, kws)
#     278         sig = template(context).apply(args, kws)
#     279         if sig:
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in get_call_template(self, args, kws)
#     299         # Ensure an overload is available
#     300         if self._can_compile:
# --> 301             self.compile(tuple(args))
#     302
#     303         # Create function type for typing
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, sig)
#     792             self._cache_misses[sig] += 1
#     793             try:
# --> 794                 cres = self._compiler.compile(args, return_type)
#     795             except errors.ForceLiteralArg as e:
#     796                 def folded(args, kws):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, args, return_type)
#      75
#      76     def compile(self, args, return_type):
# ---> 77         status, retval = self._compile_cached(args, return_type)
#      78         if status:
#      79             return retval
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_cached(self, args, return_type)
#      89
#      90         try:
# ---> 91             retval = self._compile_core(args, return_type)
#      92         except errors.TypingError as e:
#      93             self._failed_cache[key] = e
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_core(self, args, return_type)
#     102
#     103         impl = self._get_implementation(args, {})
# --> 104         cres = compiler.compile_extra(self.targetdescr.typing_context,
#     105                                       self.targetdescr.target_context,
#     106                                       impl,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     566     pipeline = pipeline_class(typingctx, targetctx, library,
#     567                               args, return_type, flags, locals)
# --> 568     return pipeline.compile_extra(func)
#     569
#     570
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(self, func)
#     337         self.state.lifted = ()
#     338         self.state.lifted_from = None
# --> 339         return self._compile_bytecode()
#     340
#     341     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_bytecode(self)
#     399         """
#     400         assert self.state.func_ir is None
# --> 401         return self._compile_core()
#     402
#     403     def _compile_ir(self):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_core(self)
#     370             res = None
#     371             try:
# --> 372                 pm.run(self.state)
#     373                 if self.state.cr is not None:
#     374                     break
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in run(self, state)
#     330                 pass_inst = _pass_registry.get(pss).pass_inst
#     331                 if isinstance(pass_inst, CompilerPass):
# --> 332                     self._runPass(idx, pass_inst, state)
#     333                 else:
#     334                     raise BaseException("Legacy pass in use")
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     289             mutated |= check(pss.run_initialization, internal_state)
#     290         with SimpleTimer() as pass_time:
# --> 291             mutated |= check(pss.run_pass, internal_state)
#     292         with SimpleTimer() as finalize_time:
#     293             mutated |= check(pss.run_finalizer, internal_state)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in check(func, compiler_state)
#     262
#     263         def check(func, compiler_state):
# --> 264             mangled = func(compiler_state)
#     265             if mangled not in (True, False):
#     266                 msg = ("CompilerPass implementations should return True/False. "
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in run_pass(self, state)
#      90                               % (state.func_id.func_name,)):
#      91             # Type inference
# ---> 92             typemap, return_type, calltypes = type_inference_stage(
#      93                 state.typingctx,
#      94                 state.func_ir,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in type_inference_stage(typingctx, interp, args, return_type, locals, raise_errors)
#      68
#      69         infer.build_constraint()
# ---> 70         infer.propagate(raise_errors=raise_errors)
#      71         typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      72
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in propagate(self, raise_errors)
#     976             # Errors can appear when the type set is incomplete; only
#     977             # raise them when there is no progress anymore.
# --> 978             errors = self.constraints.propagate(self)
#     979             newtoken = self.get_state_token()
#     980             self.debug.propagate_finished()
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in propagate(self, typeinfer)
#     147                                                    lineno=loc.line):
#     148                 try:
# --> 149                     constraint(typeinfer)
#     150                 except ForceLiteralArg as e:
#     151                     errors.append(e)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in __call__(self, typeinfer)
#     485                 fnty = typevars[self.func].getone()
#     486             with new_error_context("resolving callee type: {0}", fnty):
# --> 487                 self.resolve(typeinfer, typevars, fnty)
#     488
#     489     def resolve(self, typeinfer, typevars, fnty):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in resolve(self, typeinfer, typevars, fnty)
#     505         # Resolve call type
#     506         try:
# --> 507             sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     508         except ForceLiteralArg as e:
#     509             # Adjust for bound methods
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in resolve_call(self, fnty, pos_args, kw_args)
#    1449         else:
#    1450             # Normal non-recursive call
# -> 1451             return self.context.resolve_function_type(fnty, pos_args, kw_args)
#    1452
#    1453     def typeof_global(self, inst, target, gvar):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/context.py in resolve_function_type(self, func, args, kws)
#     195         # Prefer user definition first
#     196         try:
# --> 197             res = self._resolve_user_function_type(func, args, kws)
#     198         except errors.TypingError as e:
#     199             # Capture any typing error
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/context.py in _resolve_user_function_type(self, func, args, kws, literals)
#     247         if isinstance(func, types.Callable):
#     248             # XXX fold this into the __call__ attribute logic?
# --> 249             return func.get_call_type(self, args, kws)
#     250
#     251     def _get_attribute_templates(self, typ):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/types/functions.py in get_call_type(self, context, args, kws)
#     275         is available for it.
#     276         """
# --> 277         template, pysig, args, kws = self.dispatcher.get_call_template(args, kws)
#     278         sig = template(context).apply(args, kws)
#     279         if sig:
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in get_call_template(self, args, kws)
#     299         # Ensure an overload is available
#     300         if self._can_compile:
# --> 301             self.compile(tuple(args))
#     302
#     303         # Create function type for typing
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, sig)
#     792             self._cache_misses[sig] += 1
#     793             try:
# --> 794                 cres = self._compiler.compile(args, return_type)
#     795             except errors.ForceLiteralArg as e:
#     796                 def folded(args, kws):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, args, return_type)
#      75
#      76     def compile(self, args, return_type):
# ---> 77         status, retval = self._compile_cached(args, return_type)
#      78         if status:
#      79             return retval
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_cached(self, args, return_type)
#      89
#      90         try:
# ---> 91             retval = self._compile_core(args, return_type)
#      92         except errors.TypingError as e:
#      93             self._failed_cache[key] = e
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_core(self, args, return_type)
#     102
#     103         impl = self._get_implementation(args, {})
# --> 104         cres = compiler.compile_extra(self.targetdescr.typing_context,
#     105                                       self.targetdescr.target_context,
#     106                                       impl,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     566     pipeline = pipeline_class(typingctx, targetctx, library,
#     567                               args, return_type, flags, locals)
# --> 568     return pipeline.compile_extra(func)
#     569
#     570
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(self, func)
#     337         self.state.lifted = ()
#     338         self.state.lifted_from = None
# --> 339         return self._compile_bytecode()
#     340
#     341     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_bytecode(self)
#     399         """
#     400         assert self.state.func_ir is None
# --> 401         return self._compile_core()
#     402
#     403     def _compile_ir(self):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_core(self)
#     370             res = None
#     371             try:
# --> 372                 pm.run(self.state)
#     373                 if self.state.cr is not None:
#     374                     break
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in run(self, state)
#     330                 pass_inst = _pass_registry.get(pss).pass_inst
#     331                 if isinstance(pass_inst, CompilerPass):
# --> 332                     self._runPass(idx, pass_inst, state)
#     333                 else:
#     334                     raise BaseException("Legacy pass in use")
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     289             mutated |= check(pss.run_initialization, internal_state)
#     290         with SimpleTimer() as pass_time:
# --> 291             mutated |= check(pss.run_pass, internal_state)
#     292         with SimpleTimer() as finalize_time:
#     293             mutated |= check(pss.run_finalizer, internal_state)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in check(func, compiler_state)
#     262
#     263         def check(func, compiler_state):
# --> 264             mangled = func(compiler_state)
#     265             if mangled not in (True, False):
#     266                 msg = ("CompilerPass implementations should return True/False. "
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in run_pass(self, state)
#      90                               % (state.func_id.func_name,)):
#      91             # Type inference
# ---> 92             typemap, return_type, calltypes = type_inference_stage(
#      93                 state.typingctx,
#      94                 state.func_ir,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in type_inference_stage(typingctx, interp, args, return_type, locals, raise_errors)
#      68
#      69         infer.build_constraint()
# ---> 70         infer.propagate(raise_errors=raise_errors)
#      71         typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      72
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in propagate(self, raise_errors)
#     976             # Errors can appear when the type set is incomplete; only
#     977             # raise them when there is no progress anymore.
# --> 978             errors = self.constraints.propagate(self)
#     979             newtoken = self.get_state_token()
#     980             self.debug.propagate_finished()
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in propagate(self, typeinfer)
#     147                                                    lineno=loc.line):
#     148                 try:
# --> 149                     constraint(typeinfer)
#     150                 except ForceLiteralArg as e:
#     151                     errors.append(e)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in __call__(self, typeinfer)
#     485                 fnty = typevars[self.func].getone()
#     486             with new_error_context("resolving callee type: {0}", fnty):
# --> 487                 self.resolve(typeinfer, typevars, fnty)
#     488
#     489     def resolve(self, typeinfer, typevars, fnty):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in resolve(self, typeinfer, typevars, fnty)
#     505         # Resolve call type
#     506         try:
# --> 507             sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     508         except ForceLiteralArg as e:
#     509             # Adjust for bound methods
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in resolve_call(self, fnty, pos_args, kw_args)
#    1449         else:
#    1450             # Normal non-recursive call
# -> 1451             return self.context.resolve_function_type(fnty, pos_args, kw_args)
#    1452
#    1453     def typeof_global(self, inst, target, gvar):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/context.py in resolve_function_type(self, func, args, kws)
#     195         # Prefer user definition first
#     196         try:
# --> 197             res = self._resolve_user_function_type(func, args, kws)
#     198         except errors.TypingError as e:
#     199             # Capture any typing error
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/context.py in _resolve_user_function_type(self, func, args, kws, literals)
#     247         if isinstance(func, types.Callable):
#     248             # XXX fold this into the __call__ attribute logic?
# --> 249             return func.get_call_type(self, args, kws)
#     250
#     251     def _get_attribute_templates(self, typ):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/types/functions.py in get_call_type(self, context, args, kws)
#     275         is available for it.
#     276         """
# --> 277         template, pysig, args, kws = self.dispatcher.get_call_template(args, kws)
#     278         sig = template(context).apply(args, kws)
#     279         if sig:
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in get_call_template(self, args, kws)
#     299         # Ensure an overload is available
#     300         if self._can_compile:
# --> 301             self.compile(tuple(args))
#     302
#     303         # Create function type for typing
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, sig)
#     792             self._cache_misses[sig] += 1
#     793             try:
# --> 794                 cres = self._compiler.compile(args, return_type)
#     795             except errors.ForceLiteralArg as e:
#     796                 def folded(args, kws):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, args, return_type)
#      75
#      76     def compile(self, args, return_type):
# ---> 77         status, retval = self._compile_cached(args, return_type)
#      78         if status:
#      79             return retval
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_cached(self, args, return_type)
#      89
#      90         try:
# ---> 91             retval = self._compile_core(args, return_type)
#      92         except errors.TypingError as e:
#      93             self._failed_cache[key] = e
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_core(self, args, return_type)
#     102
#     103         impl = self._get_implementation(args, {})
# --> 104         cres = compiler.compile_extra(self.targetdescr.typing_context,
#     105                                       self.targetdescr.target_context,
#     106                                       impl,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     566     pipeline = pipeline_class(typingctx, targetctx, library,
#     567                               args, return_type, flags, locals)
# --> 568     return pipeline.compile_extra(func)
#     569
#     570
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(self, func)
#     337         self.state.lifted = ()
#     338         self.state.lifted_from = None
# --> 339         return self._compile_bytecode()
#     340
#     341     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_bytecode(self)
#     399         """
#     400         assert self.state.func_ir is None
# --> 401         return self._compile_core()
#     402
#     403     def _compile_ir(self):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_core(self)
#     370             res = None
#     371             try:
# --> 372                 pm.run(self.state)
#     373                 if self.state.cr is not None:
#     374                     break
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in run(self, state)
#     330                 pass_inst = _pass_registry.get(pss).pass_inst
#     331                 if isinstance(pass_inst, CompilerPass):
# --> 332                     self._runPass(idx, pass_inst, state)
#     333                 else:
#     334                     raise BaseException("Legacy pass in use")
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     289             mutated |= check(pss.run_initialization, internal_state)
#     290         with SimpleTimer() as pass_time:
# --> 291             mutated |= check(pss.run_pass, internal_state)
#     292         with SimpleTimer() as finalize_time:
#     293             mutated |= check(pss.run_finalizer, internal_state)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in check(func, compiler_state)
#     262
#     263         def check(func, compiler_state):
# --> 264             mangled = func(compiler_state)
#     265             if mangled not in (True, False):
#     266                 msg = ("CompilerPass implementations should return True/False. "
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in run_pass(self, state)
#      90                               % (state.func_id.func_name,)):
#      91             # Type inference
# ---> 92             typemap, return_type, calltypes = type_inference_stage(
#      93                 state.typingctx,
#      94                 state.func_ir,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in type_inference_stage(typingctx, interp, args, return_type, locals, raise_errors)
#      68
#      69         infer.build_constraint()
# ---> 70         infer.propagate(raise_errors=raise_errors)
#      71         typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      72
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in propagate(self, raise_errors)
#     976             # Errors can appear when the type set is incomplete; only
#     977             # raise them when there is no progress anymore.
# --> 978             errors = self.constraints.propagate(self)
#     979             newtoken = self.get_state_token()
#     980             self.debug.propagate_finished()
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in propagate(self, typeinfer)
#     147                                                    lineno=loc.line):
#     148                 try:
# --> 149                     constraint(typeinfer)
#     150                 except ForceLiteralArg as e:
#     151                     errors.append(e)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in __call__(self, typeinfer)
#     485                 fnty = typevars[self.func].getone()
#     486             with new_error_context("resolving callee type: {0}", fnty):
# --> 487                 self.resolve(typeinfer, typevars, fnty)
#     488
#     489     def resolve(self, typeinfer, typevars, fnty):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in resolve(self, typeinfer, typevars, fnty)
#     505         # Resolve call type
#     506         try:
# --> 507             sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     508         except ForceLiteralArg as e:
#     509             # Adjust for bound methods
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typeinfer.py in resolve_call(self, fnty, pos_args, kw_args)
#    1449         else:
#    1450             # Normal non-recursive call
# -> 1451             return self.context.resolve_function_type(fnty, pos_args, kw_args)
#    1452
#    1453     def typeof_global(self, inst, target, gvar):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/context.py in resolve_function_type(self, func, args, kws)
#     195         # Prefer user definition first
#     196         try:
# --> 197             res = self._resolve_user_function_type(func, args, kws)
#     198         except errors.TypingError as e:
#     199             # Capture any typing error
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/context.py in _resolve_user_function_type(self, func, args, kws, literals)
#     247         if isinstance(func, types.Callable):
#     248             # XXX fold this into the __call__ attribute logic?
# --> 249             return func.get_call_type(self, args, kws)
#     250
#     251     def _get_attribute_templates(self, typ):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/types/functions.py in get_call_type(self, context, args, kws)
#     275         is available for it.
#     276         """
# --> 277         template, pysig, args, kws = self.dispatcher.get_call_template(args, kws)
#     278         sig = template(context).apply(args, kws)
#     279         if sig:
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in get_call_template(self, args, kws)
#     299         # Ensure an overload is available
#     300         if self._can_compile:
# --> 301             self.compile(tuple(args))
#     302
#     303         # Create function type for typing
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, sig)
#     792             self._cache_misses[sig] += 1
#     793             try:
# --> 794                 cres = self._compiler.compile(args, return_type)
#     795             except errors.ForceLiteralArg as e:
#     796                 def folded(args, kws):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in compile(self, args, return_type)
#      75
#      76     def compile(self, args, return_type):
# ---> 77         status, retval = self._compile_cached(args, return_type)
#      78         if status:
#      79             return retval
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_cached(self, args, return_type)
#      89
#      90         try:
# ---> 91             retval = self._compile_core(args, return_type)
#      92         except errors.TypingError as e:
#      93             self._failed_cache[key] = e
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in _compile_core(self, args, return_type)
#     102
#     103         impl = self._get_implementation(args, {})
# --> 104         cres = compiler.compile_extra(self.targetdescr.typing_context,
#     105                                       self.targetdescr.target_context,
#     106                                       impl,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     566     pipeline = pipeline_class(typingctx, targetctx, library,
#     567                               args, return_type, flags, locals)
# --> 568     return pipeline.compile_extra(func)
#     569
#     570
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in compile_extra(self, func)
#     337         self.state.lifted = ()
#     338         self.state.lifted_from = None
# --> 339         return self._compile_bytecode()
#     340
#     341     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_bytecode(self)
#     399         """
#     400         assert self.state.func_ir is None
# --> 401         return self._compile_core()
#     402
#     403     def _compile_ir(self):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler.py in _compile_core(self)
#     370             res = None
#     371             try:
# --> 372                 pm.run(self.state)
#     373                 if self.state.cr is not None:
#     374                     break
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in run(self, state)
#     330                 pass_inst = _pass_registry.get(pss).pass_inst
#     331                 if isinstance(pass_inst, CompilerPass):
# --> 332                     self._runPass(idx, pass_inst, state)
#     333                 else:
#     334                     raise BaseException("Legacy pass in use")
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     289             mutated |= check(pss.run_initialization, internal_state)
#     290         with SimpleTimer() as pass_time:
# --> 291             mutated |= check(pss.run_pass, internal_state)
#     292         with SimpleTimer() as finalize_time:
#     293             mutated |= check(pss.run_finalizer, internal_state)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/compiler_machinery.py in check(func, compiler_state)
#     262
#     263         def check(func, compiler_state):
# --> 264             mangled = func(compiler_state)
#     265             if mangled not in (True, False):
#     266                 msg = ("CompilerPass implementations should return True/False. "
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in run_pass(self, state)
#     440
#     441         # TODO: Pull this out into the pipeline
# --> 442         NativeLowering().run_pass(state)
#     443         lowered = state['cr']
#     444         signature = typing.signature(state.return_type, *state.args)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typed_passes.py in run_pass(self, state)
#     395             else:
#     396                 # Prepare for execution
# --> 397                 cfunc = targetctx.get_executable(library, fndesc, env)
#     398                 # Insert native function for use by other jitted-functions.
#     399                 # We also register its library to allow for inlining.
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/cpu.py in get_executable(self, library, fndesc, env)
#     205         """
#     206         # Code generation
# --> 207         baseptr = library.get_pointer_to_function(fndesc.llvm_func_name)
#     208         fnptr = library.get_pointer_to_function(fndesc.llvm_cpython_wrapper_name)
#     209
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/codegen.py in get_pointer_to_function(self, name)
#     504             - non-zero if the symbol is defined.
#     505         """
# --> 506         self._ensure_finalized()
#     507         ee = self._codegen._engine
#     508         if not ee.is_symbol_defined(name):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/codegen.py in _ensure_finalized(self)
#     123     def _ensure_finalized(self):
#     124         if not self._finalized:
# --> 125             self.finalize()
#     126
#     127     def _optimize_functions(self, ll_module):
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/codegen.py in finalize(self)
#     243         # Optimize the module after all dependences are linked in above,
#     244         # to allow for inlining.
# --> 245         self._optimize_final_module()
#     246
#     247         self._final_module.verify()
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/codegen.py in _optimize_final_module(self)
#     143         Internal: optimize this library's final module.
#     144         """
# --> 145         self._codegen._mpm.run(self._final_module)
#     146         self._final_module = remove_redundant_nrt_refct(self._final_module)
#     147
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/llvmlite/binding/passmanagers.py in run(self, module)
#      96         Run optimization passes on the given module.
#      97         """
# ---> 98         return ffi.lib.LLVMPY_RunPassManager(self, module)
#      99
#     100
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/llvmlite/binding/ffi.py in __call__(self, *args, **kwargs)
#     112     def __call__(self, *args, **kwargs):
#     113         with self._lock:
# --> 114             return self._cfn(*args, **kwargs)
#     115
#     116
#
# KeyboardInterrupt:

# %%
br = "style='border-right: thin solid;'"
html = "<table>"
html += "<tr>"
html += f"  <td colspan=2 {br}></td>"
html += "  <td>C≈0.02</td>"
html += "  <td>C≈0.01</td>"
html += f"  <td {br} colspan=2>C≈0.005</td>"
html += "  <td colspan=2></td>"
html += "</tr>"
html += "<tr style='border-bottom: thin solid;'>"
html += "  <td>T</td>"
html += f"  <td {br}>S<sub>0</sub></td>"
html += "  <td>log<sub>2</sub>(E)</td>" * 3
html += f"  <td {br}>f(S<sub>0</sub>,0)</td>"
html += "  <td>BS93</td>"
html += "  <td>European</td>"
html += "</tr>"
last_T = None
for row in data:
    html += "<tr>"
    for col in range(len(row)):
        html += f"<td {br if col in (1, 5) else ''}>"
        if col == 0:
            if last_T != row[0]:
                html += f"{row[col]:.2f}"
                last_T = row[0]
        elif col == 1:
            html += f"{row[col]}"
        elif col < 5:
            html += f"{row[col]:.1f}"
        else:
            html += f"{row[col]:.3f}"
        html += "</td>"
    html += "</tr>"
html += "</table>"

# %%
display(HTML(html))

# %%
def check(actual, desired):
    assert actual[0] == desired[0]
    assert actual[1] == desired[1]
    assert np.round(actual[2], 1) <= desired[2]
    assert np.round(actual[3], 1) <= desired[3]
    assert np.round(actual[4], 1) <= desired[4]
    np.testing.assert_allclose(actual[5:], desired[5:], rtol=0.0005, atol=0.005)

# %%
check(actual=tabledata[0], desired=(.25,  80, -8.3, -10.2, -11.3, 19.996, 20.000, 18.089))

# %%
check(actual=tabledata[1], desired=(.25,  90, -8.1, -10.1, -11.3, 10.035, 10.011,  9.045))

# %%
check(actual=tabledata[2], desired=(.25, 100, -8.0, -10.0, -11.3,  3.228,  3.162,  3.037))

# %%
check(actual=tabledata[3], desired=(.25, 110, -8.3, -10.1, -11.3,  0.667, 0.649, 0.640))

# %%
check(actual=tabledata[4], desired=(.25, 120, -8.3, -10.1, -11.3,  0.089, 0.087, 0.086))

# %%
check(actual=tabledata[5], desired=(.5, 80, -8.7, -10.3, -11.4, 19.996, 20.000, 16.648))

# %%
check(actual=tabledata[6], desired=(.5, 90, -8.5, -10.3, -11.4, 10.290, 10.240, 8.834))

# %%
check(actual=tabledata[7], desired=(.5, 100, -8.5, -10.2, -11.3, 4.193, 4.109, 3.785))

# %%
check(actual=tabledata[8], desired=(.5, 110, -8.7, -10.3, -11.4, 1.412, 1.372, 1.312))

# %%
check(actual=tabledata[9], desired=(.5, 120, -8.7, -10.3, -11.4, 0.397, 0.385, 0.376))

# %%
check(actual=tabledata[10], desired=(3, 80, -10.3, -12.2, -13.2, 19.996, 20.000, 10.253))

# %%
check(actual=tabledata[11], desired=(3, 90, -10.3, -12.2, -13.2, 11.696, 11.668, 6.783))

# %%
check(actual=tabledata[12], desired=(3, 100, -10.3, -12.2, -13.2, 6.931, 6.896, 4.406))

# %%
check(actual=tabledata[13], desired=(3, 110, -10.3, -12.2, -13.2, 4.154, 4.118, 2.826))

# %%
check(actual=tabledata[14], desired=(3, 120, -10.3, -12.2, -13.2, 2.510, 2.478, 1.797))
