# %%
import os, sys
if 'google.colab' in sys.modules:
    # %cd /content
    if not os.path.isdir('MPyDATA'):
        # !git clone --depth 1 https://github.com/atmos-cloud-sim-uj/MPyDATA.git
    # %cd MPyDATA
    # !pip install -r requirements.txt

# %%
import os, sys
if 'google.colab' in sys.modules:
    # %cd /content/MPyDATA/MPyDATA_examples/advection_diffusion_1d
sys.path.insert(0, os.path.join(os.getcwd(), '../..'))

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

from MPyDATA import Factories
from MPyDATA.options import Options
from MPyDATA.arakawa_c.boundary_condition.periodic_boundary_condition import PeriodicBoundaryCondition

from matplotlib.animation import FuncAnimation
from IPython.display import HTML
# %matplotlib inline
#%matplotlib widget

# %%
#Eq parameters
mu = 0.05

solution_symbolic = sp.sympify("sin(pi*(x-c*t))*exp(-mu*pi**2*t) + 2", rational=True)
u0_symbolic = solution_symbolic.subs({"t":0})#sp.sympify("sin(pi * x) + 2", rational=True)

#Sim Parameters
steps_per_iter = 1
opts = Options(n_iters=3, non_zero_mu_coeff=True, infinite_gauge=True, flux_corrected_transport=True)

#Plot Parameters
r_array = np.arange(1, 7, 2)
c_array = np.linspace(0.05, 0.7, 7)

# %%
results = {}
domains = {}
solutions = {}
max_error = {}

for r in r_array:
    print(f"R {r}")
    nx = 16 * 2**r

    domain_symbolic = [-1+sp.Rational(2*i, nx) for i in range(nx)]
    domain = np.array(domain_symbolic, dtype=np.float)
    u0 = np.array([u0_symbolic.subs("x", x) for x in domain_symbolic], dtype=np.float)

    solver = Factories.advection_diffusion_1d(
        options=opts,
        advectee=u0,
        advector=0,
        boundary_conditions=(PeriodicBoundaryCondition(),)
    )

    for C in c_array:
        print("\t", C)

        #Params
        dx = 2 / nx
        phys_c = 2 * C / nx
        phys_mu = mu * dx**2
        nt = int(4 / C / dx)

        solution = solution_symbolic.subs({"c" : phys_c, "mu" : phys_mu})
        #display(solution)

        ###SIM
        solver.advector.data[0][:] = C
        solver.advectee.get()[:] = u0

        numerical_results = [solver.advectee.get().copy()]
        for i in range(nt):
            solver.advance(steps_per_iter, mu_coeff=(mu,))
            numerical_results.append(solver.advectee.get().copy())

        numerical_results = np.array(numerical_results)
        key = (r, C)
        results[key] = numerical_results
        domains[key] = domain
        solutions[key] = solution
        
        ###ERR
        u = sp.lambdify("x,t", solution)
        steps = np.arange(nt + 1, dtype=np.int).reshape(-1, 1) * steps_per_iter
        error = np.sqrt(np.sum((u(domain, steps) - numerical_results)**2, axis=1)/nx)
        max_idx = np.argmax(error)
        max_error[key] = error[max_idx]
# Out:
# R 1
# 	 0.05
# 	 0.15833333333333333
# 	 0.26666666666666666
# 	 0.37499999999999994
# 	 0.4833333333333333
# 	 0.5916666666666667
# 	 0.7
# R 3
# 	 0.05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-13747978745b> in <module>
#      37         numerical_results = [solver.curr.get().copy()]
#      38         for i in range(nt):
# ---> 39             solver.advance(steps_per_iter, mu_coeff=mu)
#      40             numerical_results.append(solver.curr.get().copy())
#      41
#
# ~/devel/MPyDATA/MPyDATA/solver.py in advance(self, nt, mu_coeff)
#      40
#      41     def advance(self, nt: int, mu_coeff: float = 0):
# ---> 42         wall_time_per_timestep = self.stepper(nt, mu_coeff,
#      43                      *self.curr.impl,
#      44                      *self.GC_phys.impl,
#
# ~/devel/MPyDATA/MPyDATA/stepper.py in __call__(self, nt, mu_coeff, psi, psi_bc, GC_phys, GC_phys_bc, g_factor, g_factor_bc, vectmp_a, vectmp_a_bc, vectmp_b, vectmp_b_bc, vectmp_c, vectmp_c_bc, psi_min, psi_min_bc, psi_max, psi_max_bc, beta_up, beta_up_bc, beta_down, beta_down_bc)
#      65              beta_down, beta_down_bc):
#      66         assert self.n_threads == 1 or numba.get_num_threads() == self.n_threads
# ---> 67         return self.__call(nt, mu_coeff,
#      68              psi, psi_bc,
#      69              GC_phys, GC_phys_bc,
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/dispatcher.py in typeof_pyval(self, val)
#     622         # can save a couple µs.
#     623         try:
# --> 624             tp = typeof(val, Purpose.argument)
#     625         except ValueError:
#     626             tp = types.pyobject
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/typeof.py in typeof(val, purpose)
#      27     # Note the behaviour for Purpose.argument must match _typeof.c.
#      28     c = _TypeofContext(purpose)
# ---> 29     ty = typeof_impl(val, c)
#      30     if ty is None:
#      31         msg = _termcolor.errmsg(
#
# /usr/lib/python3.8/functools.py in wrapper(*args, **kw)
#     872                             '1 positional argument')
#     873
# --> 874         return dispatch(args[0].__class__)(*args, **kw)
#     875
#     876     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/typing/typeof.py in _typeof_tuple(val, c)
#     158     if any(ty is None for ty in tys):
#     159         return
# --> 160     return types.BaseTuple.from_types(tys, type(val))
#     161
#     162 @typeof_impl.register(list)
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/types/containers.py in from_types(cls, tys, pyclass)
#     144                 return cls._make_homogeneous_tuple(tys[0], len(tys))
#     145             else:
# --> 146                 return cls._make_heterogeneous_tuple(tys)
#     147
#     148     @classmethod
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/types/containers.py in _make_heterogeneous_tuple(cls, tys)
#     152     @classmethod
#     153     def _make_heterogeneous_tuple(cls, tys):
# --> 154         return Tuple(tys)
#     155
#     156
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/types/abstract.py in __call__(cls, *args, **kwargs)
#      63         the new instance is returned.
#      64         """
# ---> 65         inst = type.__call__(cls, *args, **kwargs)
#      66         return cls._intern(inst)
#      67
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/types/containers.py in __new__(cls, types)
#     278     def __new__(cls, types):
#     279
# --> 280         t = utils.unified_function_type(types, require_precise=True)
#     281         if t is not None:
#     282             return UniTuple(dtype=t, count=len(types))
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/utils.py in unified_function_type(numba_types, require_precise)
#     516     for t in numba_types:
#     517         if isinstance(t, types.Dispatcher):
# --> 518             mnargs1, mxargs1 = get_nargs_range(t.dispatcher.py_func)
#     519             if mnargs is None:
#     520                 mnargs, mxargs = mnargs1, mxargs1
#
# ~/devel/MPyDATA/venv/lib/python3.8/site-packages/numba/core/utils.py in get_nargs_range(pyfunc)
#     443     positional arguments.
#     444     """
# --> 445     sig = pysignature(pyfunc)
#     446     min_nargs = 0
#     447     max_nargs = 0
#
# /usr/lib/python3.8/inspect.py in signature(obj, follow_wrapped)
#    3091 def signature(obj, *, follow_wrapped=True):
#    3092     """Get a signature object for the passed callable."""
# -> 3093     return Signature.from_callable(obj, follow_wrapped=follow_wrapped)
#    3094
#    3095
#
# /usr/lib/python3.8/inspect.py in from_callable(cls, obj, follow_wrapped)
#    2840     def from_callable(cls, obj, *, follow_wrapped=True):
#    2841         """Constructs Signature for the given callable object."""
# -> 2842         return _signature_from_callable(obj, sigcls=cls,
#    2843                                         follow_wrapper_chains=follow_wrapped)
#    2844
#
# /usr/lib/python3.8/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2290         # If it's a pure Python function, or an object that is duck type
#    2291         # of a Python function (Cython functions, for instance), then:
# -> 2292         return _signature_from_function(sigcls, obj,
#    2293                                         skip_bound_arg=skip_bound_arg)
#    2294
#
# /usr/lib/python3.8/inspect.py in _signature_from_function(cls, func, skip_bound_arg)
#    2154         kind = _POSITIONAL_ONLY if posonly_left else _POSITIONAL_OR_KEYWORD
#    2155         annotation = annotations.get(name, _empty)
# -> 2156         parameters.append(Parameter(name, annotation=annotation,
#    2157                                     kind=kind))
#    2158         if posonly_left:
#
# /usr/lib/python3.8/inspect.py in __init__(self, name, kind, default, annotation)
#    2477     def __init__(self, name, kind, *, default=_empty, annotation=_empty):
#    2478         try:
# -> 2479             self._kind = _ParameterKind(kind)
#    2480         except ValueError:
#    2481             raise ValueError(f'value {kind!r} is not a valid Parameter.kind')
#
# /usr/lib/python3.8/enum.py in __call__(cls, value, names, module, qualname, type, start)
#     276         return True
#     277
# --> 278     def __call__(cls, value, names=None, *, module=None, qualname=None, type=None, start=1):
#     279         """Either returns an existing member, or creates a new enum class.
#     280
#
# KeyboardInterrupt:

# %%
theta_array = c_array * np.pi/2

X, Y = np.meshgrid(theta_array, r_array)
Z = np.array(list(max_error.values())).reshape(len(r_array), len(theta_array))
Z = np.log2(Z)
Z[Z>0] = 0

ax = plt.subplot(111, projection='polar')

cnt = ax.contourf(X, Y, Z)
legend = plt.colorbar(cnt, ax=ax, pad=0.1)


ax.set_rlim(0, max(r_array)+1)
ax.set_thetalim(0, np.pi/2)
ax.set_rticks(range(0, max(r_array)+1))
ax.set_rlabel_position(-22.5)
theta_ticks = np.linspace(0, 90, 11)
ax.set_thetagrids(theta_ticks, theta_ticks/90)
ax.grid(True)

ax.set_title("Error log vs R and C", va='bottom')
plt.show()

# %%
key = (1,.05)
numerical_result = results[key]
domain = domains[key]
u = sp.lambdify("x,t", solutions[key])


fig = plt.figure(figsize=(9, 6))
ax = fig.add_subplot(121)
ax.set_title("Numerical and analytical solution", pad = 20)
#ax = fig.add_axes([0, 0, 1, 1], frameon=False)
ax.set_xlim(-1, 1)
ax.set_ylim(1, 3)
line, = ax.step(domain, numerical_result[0], where='mid')
line2, = ax.plot(domain, u(domain, 0))
ax = fig.add_subplot(122)
ax.set_title("Difference between analytical and numerical solution", pad = 20)
line3, = ax.plot(domain, u(domain, 0) - numerical_result[0])
ax.set_ylim(-.1, .1)
ax.set_xlim( -1, 1)

interval = 25 #ms
frame_list = np.arange(len(numerical_result), dtype=np.int)

def update(frame_num):
    line.set_ydata(numerical_result[frame_num])
    line2.set_ydata(u(domain, frame_num * steps_per_iter))
    line3.set_ydata(u(domain, frame_num * steps_per_iter) - numerical_result[frame_num])
    return line, line2, line3

animation = FuncAnimation(fig, update, frames=frame_list, interval=interval, blit=True)
fig.show()

# %%
HTML(animation.to_html5_video())
