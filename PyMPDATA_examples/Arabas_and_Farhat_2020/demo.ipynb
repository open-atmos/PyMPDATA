# %% [markdown]
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/atmos-cloud-sim-uj/PyMPDATA.git/master?filepath=PyMPDATA_examples/Arabas_and_Farhat_2020/demo.ipynb)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/atmos-cloud-sim-uj/PyMPDATA/blob/master/PyMPDATA_examples/Arabas_and_Farhat_2020/demo.ipynb)

# %%
import os, sys
if 'google.colab' in sys.modules:
    # %cd /content
    if not os.path.isdir('PyMPDATA'):
        # !git clone --depth 1 https://github.com/atmos-cloud-sim-uj/PyMPDATA.git
        # %cd PyMPDATA
    else:
        # %cd PyMPDATA
        # !git pull
    # !pip install -r requirements.txt
    # !ldconfig

# %%
import os, sys
if 'google.colab' in sys.modules:
    # %cd /content/PyMPDATA
else:
    sys.path.insert(0, os.path.join(os.getcwd(), '../..'))

# %%
# %run _demo_fig_1.ipynb
# Out:
# HTML(value="<a href='../utils/temporary_files/tmpml5j1iaw.pdf' target='_blank'>../utils/temporary_files/tmpml5…

# %%
# %run _demo_fig_2.ipynb
# Out:
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   2 out of   9 | elapsed:    6.7s remaining:   23.6s
# [Parallel(n_jobs=-2)]: Done   3 out of   9 | elapsed:    6.7s remaining:   13.5s
# [Parallel(n_jobs=-2)]: Done   4 out of   9 | elapsed:    6.7s remaining:    8.4s
# [Parallel(n_jobs=-2)]: Done   5 out of   9 | elapsed:    7.1s remaining:    5.6s
# [Parallel(n_jobs=-2)]: Done   6 out of   9 | elapsed:    7.1s remaining:    3.5s
# [Parallel(n_jobs=-2)]: Done   7 out of   9 | elapsed:    7.1s remaining:    2.0s
# [Parallel(n_jobs=-2)]: Done   9 out of   9 | elapsed:    7.1s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done   9 out of   9 | elapsed:    7.1s finished
# HTML(value="<a href='../utils/temporary_files/tmpvn21gw59.pdf' target='_blank'>../utils/temporary_files/tmpvn2…

# %%
# %run _demo_fig_3.ipynb
# Out:
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   2 out of   9 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done   3 out of   9 | elapsed:    0.2s remaining:    0.4s
# [Parallel(n_jobs=-2)]: Done   4 out of   9 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done   5 out of   9 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done   6 out of   9 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done   7 out of   9 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done   9 out of   9 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done   9 out of   9 | elapsed:    0.2s finished
# HTML(value="<a href='../utils/temporary_files/tmppq5wz_36.pdf' target='_blank'>../utils/temporary_files/tmppq5…

# %%
# %run _demo_tab_1.ipynb
# Out:
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 out of  15 | elapsed:   31.0s remaining:  1.4min
# [Parallel(n_jobs=-2)]: Done   6 out of  15 | elapsed:   34.5s remaining:   51.8s
# [Parallel(n_jobs=-2)]: Done   8 out of  15 | elapsed:  1.0min remaining:   54.4s
# [Parallel(n_jobs=-2)]: Done  10 out of  15 | elapsed:  1.1min remaining:   32.9s
# [Parallel(n_jobs=-2)]: Done  12 out of  15 | elapsed:  1.2min remaining:   17.4s
# [Parallel(n_jobs=-2)]: Done  15 out of  15 | elapsed:  1.3min finished
# ...
